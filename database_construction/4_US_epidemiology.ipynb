# %% [markdown]
# # From total test and cases from US states, the code creates a new intermediate file FULL_DATA3 to analyse them in 'covergaetest+CHI.ipynb'
# Total cases and total tests from US are retrieved from https://github.com/govex/COVID-19/tree/master/data_tables/testing_data

# %%
import seaborn as sns
import scipy.stats as stats
import numpy as np
from datetime import date
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import matplotlib.dates as mdates

# %%
dl = pd.read_csv('csv/FULL_DATA3.csv')
df1 = pd.read_csv('csv/time_series_covid19_US.csv') # total cases e totaltest https://github.com/govex/COVID-19/tree/master/data_tables/testing_data

df1=df1[['date', 'state', 'cases_confirmed', 'tests_combined_total']]
df1
df1 = df1.rename(columns={
    'state': 'country',
    'date': 'survey_date',
    'cases_confirmed': 'total_cases',
    'tests_combined_total': 'total_tests'
})
df1['survey_date'] = pd.to_datetime(df1['survey_date'])

# order by country and survey_date
df1 = df1.sort_values(['country', 'survey_date']).reset_index(drop=True)
df1 = df1[(df1['survey_date'] >= '2021-05-21') & (df1['survey_date'] <= '2022-06-25')]
print(df1)

# %%
US = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'DC': 'District of Columbia',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
    'PR': 'Puerto Rico',
    'VI': 'Virgin Islands',
    'GU': 'Guam',
    'MP': 'Northern Mariana Islands',
    'AS': 'American Samoa',
    'UM': 'U.S. Minor Outlying Islands',
    'FM': 'Federated States of Micronesia',
    'MH': 'Marshall Islands',
    'PW': 'Palau'
}

df1['country'] = df1['country'].map(US).fillna(df1['country'])
print(df1)

# %%
us = {
    'al': 'Alabama',
    'ak': 'Alaska',
    'az': 'Arizona',
    'ar': 'Arkansas',
    'ca': 'California',
    'co': 'Colorado',
    'ct': 'Connecticut',
    'de': 'Delaware',
    'dc': 'District of Columbia',
    'fl': 'Florida',
    'ga': 'Georgia',
    'hi': 'Hawaii',
    'id': 'Idaho',
    'il': 'Illinois',
    'in': 'Indiana',
    'ia': 'Iowa',
    'ks': 'Kansas',
    'ky': 'Kentucky',
    'la': 'Louisiana',
    'me': 'Maine',
    'md': 'Maryland',
    'ma': 'Massachusetts',
    'mi': 'Michigan',
    'mn': 'Minnesota',
    'ms': 'Mississippi',
    'mo': 'Missouri',
    'mt': 'Montana',
    'ne': 'Nebraska',
    'nv': 'Nevada',
    'nh': 'New Hampshire',
    'nj': 'New Jersey',
    'nm': 'New Mexico',
    'ny': 'New York',
    'nc': 'North Carolina',
    'nd': 'North Dakota',
    'oh': 'Ohio',
    'ok': 'Oklahoma',
    'or': 'Oregon',
    'pa': 'Pennsylvania',
    'ri': 'Rhode Island',
    'sc': 'South Carolina',
    'sd': 'South Dakota',
    'tn': 'Tennessee',
    'tx': 'Texas',
    'ut': 'Utah',
    'vt': 'Vermont',
    'va': 'Virginia',
    'wa': 'Washington',
    'wv': 'West Virginia',
    'wi': 'Wisconsin',
    'wy': 'Wyoming',
    'pr': 'Puerto Rico',
    'vi': 'Virgin Islands',
    'gu': 'Guam',
    'mp': 'Northern Mariana Islands',
    'as': 'American Samoa',
    'um': 'U.S. Minor Outlying Islands',
    'fm': 'Federated States of Micronesia',
    'mh': 'Marshall Islands',
    'pw': 'Palau'
}

# %%
dl["total_cases"] = None
dl["total_tests"] = None
dl

# %%
df1

# %%
# merge dataframes
dl.set_index(["country", "survey_date"], inplace=True)
df1.set_index(["country", "survey_date"], inplace=True)
dl.update(df1[["total_cases", "total_tests"]]) # aggiorna solo le colonne presenti in df1
dl.reset_index(inplace=True)   # torna al formato originale
df1.reset_index(inplace=True)

# %%
dl

# %%
dl.to_csv('csv/full_data3_con_usa.csv', index=False)
